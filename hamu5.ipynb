# %%
from yahoo_finance import Share
import requests
import base64
from bs4 import BeautifulSoup
import pandas
import sqlite3 as lite
from shutil import copyfileobj
import smtplib
import mimetypes
from email.mime.multipart import MIMEMultipart
from email import encoders
from email.message import Message
from email.mime.audio import MIMEAudio
from email.mime.base import MIMEBase
from email.mime.image import MIMEImage
from email.mime.text import MIMEText
from datetime import datetime , date 
import sys
import os
import re
from time import sleep
import mysql.connector

#define max stock id
max_stock_id = 1000

#payload data for twse
payload={}
dt_str = []
#gmail setting
emailfrom = "gghammer@gmail.com"
emailto = "gghammer@gmail.com"
#fileToSend = "daily.xlsx"
username = "gghammer"
password = "ggpudin81161"

def conn_mysql():
    try:
        server = '192.168.0.110'    
        cnx = mysql.connector.connect(user='stock', password='stock168',host= server,database='stock')  
        print("Connector to MYSQL Server:",server,"SUCCESS")
        return cnx 
    except:   
        try:
            server = 'ggnas.synology.me'
            cnx = mysql.connector.connect(user='stock', password='stock168',host= server,database='stock')   
            print("Connector to MYSQL Server:",server,"SUCCESS")
            return cnx 
        except:
            print("Connector to MYSQL Server FAIL") 
    
def send_to_gmail(source,attach_name):    
    #save to xlsx file
    twse = pandas.read_csv(source,encoding = "big5",header=1)    
    writer = pandas.ExcelWriter(attach_name, engine='xlsxwriter')
    twse.to_excel(writer, sheet_name='Sheet1')
    writer.save()

    #gmail send 
    msg = MIMEMultipart()
    msg["From"] = emailfrom
    msg["To"] = emailto
    today = date.today()    
    #msg["Subject"] = "哈墨投顧日報 "+currenttime.strftime('%Y-%m-%d')
    msg["Subject"] = "哈墨投顧日報 "+str(today)    
    msg.preamble = "help I cannot send an attachment to save my life"

    ctype, encoding = mimetypes.guess_type(attach_name)
    if ctype is None or encoding is not None:
        ctype = "application/octet-stream"

    maintype, subtype = ctype.split("/", 1)

    if maintype == "text":
        fp = open(attach_name)
        # Note: we should handle calculating the charset
        attachment = MIMEText(fp.read(), _subtype=subtype)
        fp.close()
    elif maintype == "image":
        fp = open(attach_name, "rb")
        attachment = MIMEImage(fp.read(), _subtype=subtype)
        fp.close()
    elif maintype == "audio":
        fp = open(attach_name, "rb")
        attachment = MIMEAudio(fp.read(), _subtype=subtype)
        fp.close()
    else:
        fp = open(attach_name, "rb")
        attachment = MIMEBase(maintype, subtype)
        attachment.set_payload(fp.read())
        fp.close()
        encoders.encode_base64(attachment)
    attachment.add_header("Content-Disposition", "attachment", filename=attach_name)
    msg.attach(attachment)

    server = smtplib.SMTP("smtp.gmail.com:587")
    server.starttls()
    server.login(username,password)
    server.sendmail(emailfrom, emailto, msg.as_string())
    server.quit()
    print("Send Gmail done")

def crawl_stock_id(name):  
    #catch payload 
    res = requests.post('http://www.tse.com.tw/ch/trading/exchange/BWIBBU/BWIBBU_d.php#')
    res.encoding = 'big5'

    #find key & Encryption 
    soup = BeautifulSoup(res.text, 'html.parser') 

    for inp in soup.select('input'):
        if 'hidden' in inp.get('type'): 
            payload[inp.get('name')] = base64.b64encode(inp.get('value').encode('utf-8')) 
        
    #download csw file        
    res2 = requests.post('http://www.tse.com.tw/ch/trading/exchange/BWIBBU/BWIBBU_print.php?language=ch&save=csv',data = payload ,stream = True)

    #save to twse.csv 
    f = open(name,'wb')
    copyfileobj (res2.raw,f)
    f.close()  
    
    
def crawl(target):  
    
    
    #catch payload 
    res = requests.post('http://www.tse.com.tw/ch/trading/exchange/BWIBBU/BWIBBU_d.php#')
    res.encoding = 'big5'

    #find key & Encryption 
    soup = BeautifulSoup(res.text, 'html.parser') 

    #get & translate date 
    dt = soup.select('input')[2].get('value')
    dt = dt.replace(dt[0:3], str(int(dt[0:3])+ 1911))
    dt = dt.replace(dt[4:5],'-')
    dt_str = dt.split(' ')

    for inp in soup.select('input'):
        if 'hidden' in inp.get('type'): 
            payload[inp.get('name')] = base64.b64encode(inp.get('value').encode('utf-8')) 
        
    #download csw file        
    res2 = requests.post('http://www.tse.com.tw/ch/trading/exchange/BWIBBU/BWIBBU_print.php?language=ch&save=csv',data = payload ,stream = True)

    #save to twse.csv 
    f = open('twse.csv','wb')
    copyfileobj (res2.raw,f)
    f.close()  

    #read csw to pandas 
    twse = pandas.read_csv('twse.csv',encoding = "big5",header=1)

    with lite.connect(target) as conn:   
        for i in range(0,max_stock_id):
            col = twse.iloc[i]
            col = col.tolist()
            stock_id = col[0]
            if len(stock_id)>10 :
                break
            else:    
                data = dt_str + col
                conn.execute('INSERT INTO 指標 (日期,代號,名稱,本益比,殖利率,股價淨值比) VALUES (?,?,?,?,?,?);', data)
    conn.close()
    
    print("crawl 指標 is Done")
    
def update_stock_id(name):    

    crawl_stock_id('temp.csv')
    #read csw to pandas 
    twse = pandas.read_csv('temp.csv',encoding = "big5",header=1)
    
    conn = conn_mysql()
    cursor = conn.cursor()    
    for i in range(0,max_stock_id):
        col = twse.iloc[i]
        col = col.tolist()
        del col[2:5]   
        stock_id = col[0]
        stock_name = col[1]
        if len(stock_id)>10:
            break
        else:   
            cursor.execute ("UPDATE 股票代號 SET 代號='%s',名稱='%s' WHERE ID='%d'" % (stock_id,stock_name,i+1))
           
    conn.commit()
    conn.close()  
    
    os.remove("temp.csv")
    print("Stock ID update success !")
    
def create_sql_lib(name):    
    #create sqlite lib
    conn = conn_mysql()
    cursor = conn.cursor()
    cursor.execute("""CREATE TABLE 股票代號 (
                                            ID   INT(12) NOT NULL AUTO_INCREMENT PRIMARY KEY,
                                            代號 VARCHAR(10)CHARACTER SET utf8 COLLATE utf8_general_ci,
                                            名稱 VARCHAR(10)CHARACTER SET utf8 COLLATE utf8_general_ci )""")
    cursor.execute("""CREATE TABLE 股價 (
                                        ID   INT(12) NOT NULL AUTO_INCREMENT PRIMARY KEY,
                                        日期 DATE,
                                        代號 VARCHAR(8) CHARACTER SET utf8 COLLATE utf8_general_ci,
                                        名稱 VARCHAR(8) CHARACTER SET utf8 COLLATE utf8_general_ci,
                                        開盤價 VARCHAR(8) CHARACTER SET utf8 COLLATE utf8_general_ci,
                                        收盤價 VARCHAR(8) CHARACTER SET utf8 COLLATE utf8_general_ci,
                                        漲跌 VARCHAR(8) CHARACTER SET utf8 COLLATE utf8_general_ci,
                                        漲跌百分比 VARCHAR(8) CHARACTER SET utf8 COLLATE utf8_general_ci,
                                        最高 VARCHAR(8) CHARACTER SET utf8 COLLATE utf8_general_ci,
                                        最低 VARCHAR(8) CHARACTER SET utf8 COLLATE utf8_general_ci,
                                        日量 VARCHAR(8) CHARACTER SET utf8 COLLATE utf8_general_ci,
                                        均線50 VARCHAR(8) CHARACTER SET utf8 COLLATE utf8_general_ci,
                                        均線200 VARCHAR(8) CHARACTER SET utf8 COLLATE utf8_general_ci,
                                        本益比 VARCHAR(8) CHARACTER SET utf8 COLLATE utf8_general_ci,
                                        殖利率 VARCHAR(8) CHARACTER SET utf8 COLLATE utf8_general_ci,
                                        股價淨值比 VARCHAR(8) CHARACTER SET utf8 COLLATE utf8_general_ci)""")          

    cursor.execute("""CREATE TABLE 指標 (
                                         ID   INT(12) NOT NULL AUTO_INCREMENT PRIMARY KEY,       
                                         日期 DATE ,
                                         代號 VARCHAR(8) CHARACTER SET utf8 COLLATE utf8_general_ci,
                                         名稱 VARCHAR(8) CHARACTER SET utf8 COLLATE utf8_general_ci, 
                                         本益比 VARCHAR(8) CHARACTER SET utf8 COLLATE utf8_general_ci,
                                         殖利率 VARCHAR(8) CHARACTER SET utf8 COLLATE utf8_general_ci,
                                         股價淨值比 VARCHAR(8) CHARACTER SET utf8 COLLATE utf8_general_ci)""")    
    
    cursor.execute("""CREATE TABLE 營收 (
                                         ID   INT(12) NOT NULL AUTO_INCREMENT PRIMARY KEY,       
                                        日期 DATE,
                                        代號 VARCHAR(8) CHARACTER SET utf8 COLLATE utf8_general_ci,
                                        名稱 VARCHAR(8) CHARACTER SET utf8 COLLATE utf8_general_ci,
                                        EPS VARCHAR(8) CHARACTER SET utf8 COLLATE utf8_general_ci,
                                        月營收 VARCHAR(8) CHARACTER SET utf8 COLLATE utf8_general_ci,
                                        季營收 VARCHAR(8) CHARACTER SET utf8 COLLATE utf8_general_ci,
                                        年營收 VARCHAR(8) CHARACTER SET utf8 COLLATE utf8_general_ci,
                                        配息 VARCHAR(8) CHARACTER SET utf8 COLLATE utf8_general_ci,
                                        配股 VARCHAR(8) CHARACTER SET utf8 COLLATE utf8_general_ci)""")
    
    print ("MySQL LIB created successfully")  
    
    
    crawl_stock_id('temp.csv')
    
    #read csw to pandas 
    twse = pandas.read_csv('temp.csv',encoding = "big5",header=1)

    #update to sqlite file 
    for i in range(0,max_stock_id):
        col = twse.iloc[i]
        col = col.tolist()
        del col[2:5]
        if len(col[0]) >10:
            break
        else:    
            cursor.execute("INSERT INTO 股票代號 (代號,名稱) VALUES ('%s','%s')"%(col[0],col[1]))   
    conn.commit()           
    conn.close()      

    
    os.remove("temp.csv")
    print ("Stock ID created successfully") 
    
    
def getStock_history(id,start,end):
    stock = Share(str(id)+'.TW')
    data = stock.get_historical(start, end)
    return data


def crawl_history(target):     
    today = date.today() #todays date 
    conn = conn_mysql()
    cursor = conn.cursor(buffered = True)
    cursor.execute("SELECT * FROM 股票代號") 
    for i in range(0,max_stock_id):             
        sql = cursor.fetchone()
        print(sql)
        if sql:    
            try:
                print(sql[2])
                stock = getStock_history(sql[1],'2008-01-01',str(today))    
                for i in range(0,len(stock)):                            
                    data = stock[i]
                    if data['Date']:
                        stock_date = data['Date']
                    if data['Open']:  
                        stock_open = data['Open']
                    if data['High']:                         
                        stock_high = data['High']
                    if data['Low']:                         
                        stock_low = data['Low']
                    if data['Close']:         
                        stock_close = data['Close']
                    if data['Volume']:
                        stock_volume = (int(data['Volume'])/1000)
                    if int(stock_volume):      
                        #sql_list = [stock_date]+[sql[0]]+[sql[1]]+[stock_open]+[stock_close]+[stock_high]+[stock_low]+[stock_volume]
                        cursor2 = conn.cursor(buffered = True)
                        cursor2.execute("INSERT INTO 股價 (日期,代號,名稱,開盤價,收盤價,最高,最低,日量) VALUES ('%s','%s','%s','%s','%s','%s','%s','%d')"%(stock_date,sql[1],sql[2],stock_open,stock_high,stock_low,stock_close,stock_volume))                     
                conn.commit()    
                print(datetime.now())  
            except:
                print("Not support ID =",sql[0])            
    conn.close()    
    print("Crawl history is done")
                        
#main   
def main(fucntion):
        
#    if fucntion == 'create_lib':
#    create_sql_lib('stock.sqlite')      
        
#    elif fucntion == 'update_stock_id':conn.commit(
#    update_stock_id('stock.sqlite')  
    
#    elif fucntion == 'crawl':      
#        crawl('stock.sqlite')  #target sql file name , para    
    stock = crawl_history('stock.sqlite')  
#    elif fucntion == 'crawl_history':      
#        stock = crawl_history('stock.sqlite')   
#    elif fucntion == 'report':
#        send_to_gmail('twse.csv','daily.xlsx') #source pandas structure , target excel file name        
#    else:
#        print(' Usag   hamu create_lib          #建立資料庫')
#        print('        hamu update_stock_id     #更新股票代號')
#        print('        hamu crawl               #爬當日資料')
#        print('        hamu crawl               #爬歷史資料')
#        print('        hamu report              #透過gmail寄出電子報')
        
        
if __name__ == '__main__':
    main(sys.argv[1])
# Out:
# Connector to MYSQL Server: 192.168.0.110 SUCCESS
# (1, '1101', '台泥')
# 台泥
# 2017-03-23 23:56:06.150628
# (2, '1102', '亞泥')
# 亞泥
# 2017-03-23 23:56:50.675853
# (3, '1103', '嘉泥')
# 嘉泥
# 2017-03-23 23:58:08.680023
# (4, '1104', '環泥')
# 環泥
# 2017-03-23 23:58:32.955625
# (5, '1108', '幸福')
# 幸福
# 2017-03-23 23:58:51.132701
# (6, '1109', '信大')
# 信大
# 2017-03-23 23:59:11.331102
# (7, '1110', '東泥')
# 東泥
# 2017-03-23 23:59:27.846971
# (8, '1201', '味全')
# 味全
# 2017-03-24 00:00:00.222620
# (9, '1203', '味王')
# 味王
# 2017-03-24 00:00:17.783183
# (10, '1210', '大成')
# 大成
# 2017-03-24 00:00:42.031238
# (11, '1213', '大飲')
# 大飲
# 2017-03-24 00:00:59.043137
# (12, '1215', '卜蜂')
# 卜蜂
# 2017-03-24 00:01:39.003635
# (13, '1216', '統一')
# 統一
# 2017-03-24 00:02:32.323394
# (14, '1217', '愛之味')
# 愛之味
# 2017-03-24 00:02:49.148109
# (15, '1218', '泰山')
# 泰山
# 2017-03-24 00:03:07.976959
# (16, '1219', '福壽')
# 福壽
# Not support ID = 16
# (17, '1220', '台榮')
# 台榮
# 2017-03-24 00:03:36.789756
# (18, '1225', '福懋油')
# 福懋油
# 2017-03-24 00:03:57.378716
# (19, '1227', '佳格')
# 佳格
# Not support ID = 19
# (20, '1229', '聯華')
# 聯華
# 2017-03-24 00:04:47.304526
# (21, '1231', '聯華食')
# 聯華食
# 2017-03-24 00:05:05.677094
# (22, '1232', '大統益')
# 大統益
# 2017-03-24 00:05:22.925811
# (23, '1233', '天仁')
# 天仁
# 2017-03-24 00:05:38.568125
# (24, '1234', '黑松')
# 黑松
# 2017-03-24 00:05:55.142199
# (25, '1235', '興泰')
# 興泰
# 2017-03-24 00:06:11.261622
# (26, '1236', '宏亞')
# 宏亞
# 2017-03-24 00:06:29.571560
# (27, '1256', '鮮活果汁-KY')
# 鮮活果汁-KY
# Not support ID = 27
# (28, '1262', '綠悅-KY')
# 綠悅-KY
# Not support ID = 28
# (29, '1301', '台塑')
# 台塑
# 2017-03-24 00:06:51.607374
# (30, '1303', '南亞')
# 南亞
# 2017-03-24 00:07:13.392377
# (31, '1304', '台聚')
# 台聚
# 2017-03-24 00:07:42.995412
# (32, '1305', '華夏')
# 華夏
# 2017-03-24 00:08:05.146884
# (33, '1307', '三芳')
# 三芳
# Not support ID = 33
# (34, '1308', '亞聚')
# 亞聚
# 2017-03-24 00:08:40.341180
# (35, '1309', '台達化')
# 台達化
# 2017-03-24 00:08:56.136968
# (36, '1310', '台苯')
# 台苯
# 2017-03-24 00:09:12.294330
# (37, '1312', '國喬')
# 國喬
# 2017-03-24 00:09:30.274092
# (38, '1313', '聯成')
# 聯成
# 2017-03-24 00:09:54.683354
# (39, '1314', '中石化')
# 中石化
# Not support ID = 39
# (40, '1315', '達新')
# 達新
# 2017-03-24 00:10:33.790690
# (41, '1316', '上曜')
# 上曜
# 2017-03-24 00:10:48.898424
# (42, '1319', '東陽')
# 東陽
# 2017-03-24 00:11:04.596409
# (43, '1321', '大洋')
# 大洋
# 2017-03-24 00:11:25.158829
# (44, '1323', '永裕')
# 永裕
# 2017-03-24 00:11:41.847055
# (45, '1324', '地球')
# 地球
# 2017-03-24 00:11:56.820110
# (46, '1325', '恆大')
# 恆大
# 2017-03-24 00:12:29.173774
# (47, '1326', '台化')
# 台化
# Not support ID = 47
# (48, '1337', '再生-KY')
# 再生-KY
# Not support ID = 48
# (49, '1338', '廣華-KY')
# 廣華-KY
# Not support ID = 49
# (50, '1339', '昭輝')
# 昭輝
# Not support ID = 50
# (51, '1340', '勝悅-KY')
# 勝悅-KY
# Not support ID = 51
# (52, '1402', '遠東新')
# 遠東新
# 2017-03-24 00:13:31.281462
# (53, '1409', '新纖')
# 新纖
# 2017-03-24 00:13:52.993783
# (54, '1410', '南染')
# 南染
# 2017-03-24 00:14:07.212301
# (55, '1413', '宏洲')
# 宏洲
# 2017-03-24 00:14:29.174738
# (56, '1414', '東和')
# 東和
# 2017-03-24 00:14:44.747803
# (57, '1416', '廣豐')
# 廣豐
# 2017-03-24 00:14:59.485562
# (58, '1417', '嘉裕')
# 嘉裕
# 2017-03-24 00:15:16.140462
# (59, '1418', '東華')
# 東華
# 2017-03-24 00:15:34.950845
# (60, '1419', '新紡')
# 新紡
# 2017-03-24 00:16:30.546989
# (61, '1423', '利華')
# 利華
# 2017-03-24 00:16:44.985864
# (62, '1432', '大魯閣')
# 大魯閣
# 2017-03-24 00:17:05.084507
# (63, '1434', '福懋')
# 福懋
# 2017-03-24 00:17:28.874182
# (64, '1435', '中福')
# 中福
# 2017-03-24 00:17:51.963048
# (65, '1436', '華友聯')
# 華友聯
# 2017-03-24 00:18:11.265357
# (66, '1437', '勤益控')
# 勤益控
# 2017-03-24 00:18:34.611175
# (67, '1438', '裕豐')
# 裕豐
# 2017-03-24 00:18:48.783945
# (68, '1439', '中和')
# 中和
# 2017-03-24 00:19:04.275357
# (69, '1440', '南紡')
# 南紡
# 2017-03-24 00:19:22.314293
# (70, '1441', '大東')
# 大東
# 2017-03-24 00:19:39.407172
# (71, '1442', '名軒')
# 名軒
# 2017-03-24 00:19:55.757800
# (72, '1443', '立益')
# 立益
# 2017-03-24 00:20:15.105172
# (73, '1444', '力麗')
# 力麗
# 2017-03-24 00:20:34.463873
# (74, '1445', '大宇')
# 大宇
# 2017-03-24 00:20:51.585905
# (75, '1446', '宏和')
# 宏和
# 2017-03-24 00:21:12.195347
# (76, '1447', '力鵬')
# 力鵬
# 2017-03-24 00:21:30.845021
# (77, '1449', '佳和')
# 佳和
# 2017-03-24 00:21:46.552520
# (78, '1451', '年興')
# 年興
# 2017-03-24 00:22:13.742557
# (79, '1452', '宏益')
# 宏益
# 2017-03-24 00:22:32.996851
# (80, '1453', '大將')
# 大將
# 2017-03-24 00:22:49.468329
# (81, '1454', '台富')
# 台富
# 2017-03-24 00:23:08.019209
# (82, '1455', '集盛')
# 集盛
# Not support ID = 82
# (83, '1456', '怡華')
# 怡華
# 2017-03-24 00:23:46.098219
# (84, '1459', '聯發')
# 聯發
# 2017-03-24 00:24:03.251582
# (85, '1460', '宏遠')
# 宏遠
# 2017-03-24 00:24:31.454767
# (86, '1463', '強盛')
# 強盛
# 2017-03-24 00:24:49.241660
# (87, '1464', '得力')
# 得力
# 2017-03-24 00:25:09.925439
# (88, '1465', '偉全')
# 偉全
# 2017-03-24 00:25:29.308195
# (89, '1466', '聚隆')
# 聚隆
# 2017-03-24 00:25:46.181449
# (90, '1467', '南緯')
# 南緯
# 2017-03-24 00:26:03.819205
# (91, '1468', '昶和')
# 昶和
# Not support ID = 91
# (92, '1469', '理隆')
# 理隆
# 2017-03-24 00:26:40.778065
# (93, '1470', '大統染')
# 大統染
# 2017-03-24 00:26:58.799121
# (94, '1471', '首利')
# 首利
# 2017-03-24 00:27:22.958083
# (95, '1472', '三洋紡')
# 三洋紡
# 2017-03-24 00:27:41.447086
# (96, '1473', '台南')
# 台南
# 2017-03-24 00:27:57.597985
# (97, '1474', '弘裕')
# 弘裕
# 2017-03-24 00:28:18.895158
# (98, '1475', '本盟')
# 本盟
# 2017-03-24 00:28:38.084696
# (99, '1476', '儒鴻')
# 儒鴻
# Not support ID = 99
# (100, '1477', '聚陽')
# 聚陽
# 2017-03-24 00:29:15.039130
# (101, '1503', '士電')
# 士電
# 2017-03-24 00:29:30.179092
# (102, '1504', '東元')
# 東元
# 2017-03-24 00:29:45.280418
# (103, '1506', '正道')
# 正道
# 2017-03-24 00:30:00.733613
# (104, '1507', '永大')
# 永大
# 2017-03-24 00:30:17.945666
# (105, '1512', '瑞利')
# 瑞利
# 2017-03-24 00:30:33.684554
# (106, '1513', '中興電')
# 中興電
# 2017-03-24 00:30:51.306152
# (107, '1514', '亞力')
# 亞力
# 2017-03-24 00:31:07.317257
# (108, '1515', '力山')
# 力山
# 2017-03-24 00:31:30.776584
# (109, '1516', '川飛')
# 川飛
# 2017-03-24 00:31:47.376889
# (110, '1517', '利奇')
# 利奇
# 2017-03-24 00:32:04.486521
# (111, '1519', '華城')
# 華城
# Not support ID = 111
# (112, '1521', '大億')
# 大億
# 2017-03-24 00:32:38.267949
# (113, '1522', '堤維西')
# 堤維西
# 2017-03-24 00:32:55.066251
# (114, '1524', '耿鼎')
# 耿鼎
# 2017-03-24 00:33:10.761899
# (115, '1525', '江申')
# 江申
# Not support ID = 115
# (116, '1526', '日馳')
# 日馳
# 2017-03-24 00:34:00.206968
# (117, '1527', '鑽全')
# 鑽全
# Not support ID = 117
# (118, '1528', '恩德')
# 恩德
# 2017-03-24 00:34:46.398136
# (119, '1529', '樂士')
# 樂士
# 2017-03-24 00:35:01.140438
# (120, '1530', '亞崴')
# 亞崴
# 2017-03-24 00:35:22.206181
# (121, '1531', '高林股')
# 高林股
# 2017-03-24 00:35:38.271154
# (122, '1532', '勤美')
# 勤美
# 2017-03-24 00:36:31.456043
# (123, '1533', '車王電')
# 車王電
# 2017-03-24 00:36:46.975630
# (124, '1535', '中宇')
# 中宇
# 2017-03-24 00:37:03.185801
# (125, '1536', '和大')
# 和大
# Not support ID = 125
# (126, '1537', '廣隆')
# 廣隆
# 2017-03-24 00:37:41.499856
# (127, '1538', '正峰新')
# 正峰新
# 2017-03-24 00:37:57.791858
# (128, '1539', '巨庭')
# 巨庭
# 2017-03-24 00:38:14.581151
# (129, '1540', '喬福')
# 喬福
# 2017-03-24 00:38:32.521604
# (130, '1541', '錩泰')
# 錩泰
# 2017-03-24 00:38:47.035413
# (131, '1558', '伸興')
# 伸興
# 2017-03-24 00:39:04.392252
# (132, '1560', '中砂')
# 中砂
# Not support ID = 132
# (133, '1568', '倉佑')
# 倉佑
# Not support ID = 133
# (134, '1582', '信錦')
# 信錦
# Not support ID = 134
# (135, '1583', '程泰')
# 程泰
# 2017-03-24 00:40:08.369211
# (136, '1589', '永冠-KY')
# 永冠-KY
# Not support ID = 136
# (137, '1590', '亞德客-KY')
# 亞德客-KY
# Not support ID = 137
# (138, '1592', '英瑞-KY')
# 英瑞-KY
# Not support ID = 138
# (139, '1598', '岱宇')
# 岱宇
# Not support ID = 139
# (140, '1603', '華電')
# 華電
# 2017-03-24 00:41:03.389360
# (141, '1604', '聲寶')
# 聲寶
# Not support ID = 141
# (142, '1605', '華新')
# 華新
# 2017-03-24 00:41:44.454390
# (143, '1608', '華榮')
# 華榮
# 2017-03-24 00:42:02.107155
# (144, '1609', '大亞')
# 大亞
# Not support ID = 144
# (145, '1611', '中電')
# 中電
# 2017-03-24 00:42:44.551267
# (146, '1612', '宏泰')
# 宏泰
# 2017-03-24 00:43:03.758304
# (147, '1613', '台一')
# 台一
# Not support ID = 147
# (148, '1614', '三洋電')
# 三洋電
# 2017-03-24 00:43:49.845190
# (149, '1615', '大山')
# 大山
# 2017-03-24 00:44:07.522217
# (150, '1616', '億泰')
# 億泰
# Not support ID = 150
# (151, '1617', '榮星')
# 榮星
# 2017-03-24 00:44:51.592136
# (152, '1618', '合機')
# 合機
# 2017-03-24 00:45:08.458264
# (153, '1626', '艾美特-KY')
# 艾美特-KY
# Not support ID = 153
# (154, '1701', '中化')
# 中化
# 2017-03-24 00:45:39.228603
# (155, '1702', '南僑')
# 南僑
# 2017-03-24 00:45:54.950346
# (156, '1704', '榮化')
# 榮化
# 2017-03-24 00:46:11.982087
# (157, '1707', '葡萄王')
# 葡萄王
# 2017-03-24 00:46:33.132438
# (158, '1708', '東鹼')
# 東鹼
# 2017-03-24 00:46:49.542364
# (159, '1709', '和益')
# 和益
# 2017-03-24 00:47:11.832508
# (160, '1710', '東聯')
# 東聯
# Not support ID = 160
# (161, '1711', '永光')
# 永光
# Not support ID = 161
# (162, '1712', '興農')
# 興農
# 2017-03-24 00:48:20.724238
# (163, '1713', '國化')
# 國化
# 2017-03-24 00:48:39.747342
# (164, '1714', '和桐')
# 和桐
# 2017-03-24 00:48:59.439286
# (165, '1715', '萬洲')
# 萬洲
# 2017-03-24 00:49:20.463515
# (166, '1717', '長興')
# 長興
# 2017-03-24 00:49:42.311440
# (167, '1718', '中纖')
# 中纖
# 2017-03-24 00:50:04.928530
# (168, '1720', '生達')
# 生達
# 2017-03-24 00:50:29.715943
# (169, '1721', '三晃')
# 三晃
# 2017-03-24 00:50:48.378569
# (170, '1722', '台肥')
# 台肥
# 2017-03-24 00:51:05.746914
# (171, '1723', '中碳')
# 中碳
# Not support ID = 171
# (172, '1724', '台硝')
# 台硝
# 2017-03-24 00:51:49.090220
# (173, '1725', '元禎')
# 元禎
# 2017-03-24 00:52:09.775858
# (174, '1726', '永記')
# 永記
# 2017-03-24 00:52:31.964939
# (175, '1727', '中華化')
# 中華化
# 2017-03-24 00:52:54.253067
# (176, '1729', '必翔')
# 必翔
# 2017-03-24 00:53:21.511246
# (177, '1730', '花仙子')
# 花仙子
# 2017-03-24 00:53:41.968514
# (178, '1731', '美吾華')
# 美吾華
# 2017-03-24 00:54:01.467265
# (179, '1732', '毛寶')
# 毛寶
# 2017-03-24 00:54:20.398458
# (180, '1733', '五鼎')
# 五鼎
# 2017-03-24 00:54:38.351476
# (181, '1734', '杏輝')
# 杏輝
# 2017-03-24 00:55:03.754839
# (182, '1735', '日勝化')
# 日勝化
# 2017-03-24 00:55:28.236719
# (183, '1736', '喬山')
# 喬山
# Not support ID = 183
# (184, '1737', '臺鹽')
# 臺鹽
# 2017-03-24 00:56:05.100364
# (185, '1762', '中化生')
# 中化生
# Not support ID = 185
# (186, '1773', '勝一')
# 勝一
# Not support ID = 186
# (187, '1776', '展宇')
# 展宇
# Not support ID = 187
# (188, '1783', '和康生')
# 和康生
# Not support ID = 188
# (189, '1786', '科妍')
# 科妍
# Not support ID = 189
# (190, '1789', '神隆')
# 神隆
# Not support ID = 190
# (191, '1802', '台玻')
# 台玻
# 2017-03-24 00:57:35.757362
# (192, '1805', '寶徠')
# 寶徠
# 2017-03-24 00:57:51.522825
# (193, '1806', '冠軍')
# 冠軍
# 2017-03-24 00:58:08.983050
# (194, '1808', '潤隆')
# 潤隆
# 2017-03-24 00:58:32.009580
# (195, '1809', '中釉')
# 中釉
# 2017-03-24 00:58:50.933086
# (196, '1810', '和成')
# 和成
# 2017-03-24 00:59:10.897778
# (197, '1817', '凱撒衛')
# 凱撒衛
# Not support ID = 197
# (198, '1902', '台紙')
# 台紙
# 2017-03-24 00:59:41.373923
# (199, '1903', '士紙')
# 士紙
# 2017-03-24 01:00:01.847805
# (200, '1904', '正隆')
# 正隆
# 2017-03-24 01:00:25.256096
# (201, '1905', '華紙')
# 華紙
# 2017-03-24 01:00:49.497772
# (202, '1906', '寶隆')
# 寶隆
# 2017-03-24 01:01:07.177997
# (203, '1907', '永豐餘')
# 永豐餘
# 2017-03-24 01:01:28.946267
# (204, '1909', '榮成')
# 榮成
# 2017-03-24 01:01:47.164669
# (205, '2002', '中鋼')
# 中鋼
# 2017-03-24 01:02:05.698782
# (206, '2006', '東和鋼鐵')
# 東和鋼鐵
# 2017-03-24 01:02:26.922006
# (207, '2007', '燁興')
# 燁興
# 2017-03-24 01:02:45.946930
# (208, '2008', '高興昌')
# 高興昌
# 2017-03-24 01:03:07.705953
# (209, '2009', '第一銅')
# 第一銅
# Not support ID = 209
# (210, '2010', '春源')
# 春源
# 2017-03-24 01:03:41.697541
# (211, '2012', '春雨')
# 春雨
# 2017-03-24 01:03:59.265185
# (212, '2013', '中鋼構')
# 中鋼構
# Not support ID = 212
# (213, '2014', '中鴻')
# 中鴻
# Not support ID = 213
# (214, '2015', '豐興')
# 豐興
# Not support ID = 214
# (215, '2017', '官田鋼')
# 官田鋼
# Not support ID = 215
# (216, '2020', '美亞')
# 美亞
# Not support ID = 216
# (217, '2022', '聚亨')
# 聚亨
# Not support ID = 217
# (218, '2023', '燁輝')
# 燁輝
# Not support ID = 218
# (219, '2024', '志聯')
# 志聯
# Not support ID = 219
# (220, '2025', '千興')
# 千興
# Not support ID = 220
# (221, '2027', '大成鋼')
# 大成鋼
# Not support ID = 221
# (222, '2028', '威致')
# 威致
# Not support ID = 222
# (223, '2029', '盛餘')
# 盛餘
# Not support ID = 223
# (224, '2030', '彰源')
# 彰源
# Not support ID = 224
# (225, '2031', '新光鋼')
# 新光鋼
# Not support ID = 225
# (226, '2032', '新鋼')
# 新鋼
# Not support ID = 226
# (227, '2033', '佳大')
# 佳大
# Not support ID = 227
# (228, '2034', '允強')
# 允強
# Not support ID = 228
# (229, '2038', '海光')
# 海光
# Not support ID = 229
# (230, '2049', '上銀')
# 上銀
# Not support ID = 230
# (231, '2059', '川湖')
# 川湖
# Not support ID = 231
# (232, '2062', '橋椿')
# 橋椿
# Not support ID = 232
# (233, '2069', '運錩')
# 運錩
# Not support ID = 233
# (234, '2101', '南港')
# 南港
# Not support ID = 234
# (235, '2102', '泰豐')
# 泰豐
# Not support ID = 235
# (236, '2103', '台橡')
# 台橡
# Not support ID = 236
# (237, '2104', '中橡')
# 中橡
# Not support ID = 237
# (238, '2105', '正新')
# 正新
# Not support ID = 238
# (239, '2106', '建大')
# 建大
# Not support ID = 239
# (240, '2107', '厚生')
# 厚生
# Not support ID = 240
# (241, '2108', '南帝')
# 南帝
# Not support ID = 241
# (242, '2109', '華豐')
# 華豐
# Not support ID = 242
# (243, '2114', '鑫永銓')
# 鑫永銓
# Not support ID = 243
# (244, '2115', '六暉-KY')
# 六暉-KY
# Not support ID = 244
# (245, '2201', '裕隆')
# 裕隆
# Not support ID = 245
# (246, '2204', '中華')
# 中華
# Not support ID = 246
# (247, '2206', '三陽工業')
# 三陽工業
# Not support ID = 247
# (248, '2207', '和泰車')
# 和泰車
# Not support ID = 248
# (249, '2208', '台船')
# 台船
# Not support ID = 249
# (250, '2227', '裕日車')
# 裕日車
# Not support ID = 250
# (251, '2228', '劍麟')
# 劍麟
# Not support ID = 251
# (252, '2231', '為升')
# 為升
# Not support ID = 252
# (253, '2236', '百達-KY')
# 百達-KY
# Not support ID = 253
# (254, '2239', '英利-KY')
# 英利-KY
# Not support ID = 254
# (255, '2301', '光寶科')
# 光寶科
# Not support ID = 255
# (256, '2302', '麗正')
# 麗正
# Not support ID = 256
# (257, '2303', '聯電')
# 聯電
# Not support ID = 257
# (258, '2305', '全友')
# 全友
# Not support ID = 258
# (259, '2308', '台達電')
# 台達電
# Not support ID = 259
# (260, '2311', '日月光')
# 日月光
# Not support ID = 260
# (261, '2312', '金寶')
# 金寶
# Not support ID = 261
# (262, '2313', '華通')
# 華通
# Not support ID = 262
# (263, '2314', '台揚')
# 台揚
# Not support ID = 263
# (264, '2316', '楠梓電')
# 楠梓電
# Not support ID = 264
# (265, '2317', '鴻海')
# 鴻海
# Not support ID = 265
# (266, '2321', '東訊')
# 東訊
# Not support ID = 266
# (267, '2323', '中環')
# 中環
# Not support ID = 267
# (268, '2324', '仁寶')
# 仁寶
# Not support ID = 268
# (269, '2325', '矽品')
# 矽品
# Not support ID = 269
# (270, '2327', '國巨')
# 國巨
# Not support ID = 270
# (271, '2328', '廣宇')
# 廣宇
# Not support ID = 271
# (272, '2329', '華泰')
# 華泰
# Not support ID = 272
# (273, '2330', '台積電')
# 台積電
# Not support ID = 273
# (274, '2331', '精英')
# 精英
# Not support ID = 274
# (275, '2332', '友訊')
# 友訊
# Not support ID = 275
# (276, '2337', '旺宏')
# 旺宏
# Not support ID = 276
# (277, '2338', '光罩')
# 光罩
# Not support ID = 277
# (278, '2340', '光磊')
# 光磊
# Not support ID = 278
# (279, '2342', '茂矽')
# 茂矽
# Not support ID = 279
# (280, '2344', '華邦電')
# 華邦電
# Not support ID = 280
# (281, '2345', '智邦')
# 智邦
# Not support ID = 281
# (282, '2347', '聯強')
# 聯強
# Not support ID = 282
# (283, '2348', '海悅')
# 海悅
# Not support ID = 283
# (284, '2349', '錸德')
# 錸德
# Not support ID = 284
# (285, '2351', '順德')
# 順德
# Not support ID = 285
# (286, '2352', '佳世達')
# 佳世達
# Not support ID = 286
# (287, '2353', '宏??')
# 宏??
# Not support ID = 287
# (288, '2354', '鴻準')
# 鴻準
# Not support ID = 288
# (289, '2355', '敬鵬')
# 敬鵬
# Not support ID = 289
# (290, '2356', '英業達')
# 英業達
# Not support ID = 290
# (291, '2357', '華碩')
# 華碩
# Not support ID = 291
# (292, '2358', '廷鑫')
# 廷鑫
# Not support ID = 292
# (293, '2359', '所羅門')
# 所羅門
# Not support ID = 293
# (294, '2360', '致茂')
# 致茂
# Not support ID = 294
# (295, '2362', '藍天')
# 藍天
# Not support ID = 295
# (296, '2363', '矽統')
# 矽統
# Not support ID = 296
# (297, '2364', '倫飛')
# 倫飛
# Not support ID = 297
# (298, '2365', '昆盈')
# 昆盈
# Not support ID = 298
# (299, '2367', '燿華')
# 燿華
# Not support ID = 299
# (300, '2368', '金像電')
# 金像電
# Not support ID = 300
# (301, '2369', '菱生')
# 菱生
# Not support ID = 301
# (302, '2371', '大同')
# 大同
# Not support ID = 302
# (303, '2373', '震旦行')
# 震旦行
# Not support ID = 303
# (304, '2374', '佳能')
# 佳能
# Not support ID = 304
# (305, '2375', '智寶')
# 智寶
# Not support ID = 305
# (306, '2376', '技嘉')
# 技嘉
# Not support ID = 306
# (307, '2377', '微星')
# 微星
# Not support ID = 307
# (308, '2379', '瑞昱')
# 瑞昱
# Not support ID = 308
# (309, '2380', '虹光')
# 虹光
# Not support ID = 309
# (310, '2382', '廣達')
# 廣達
# Not support ID = 310
# (311, '2383', '台光電')
# 台光電
# Not support ID = 311
# (312, '2385', '群光')
# 群光
# Not support ID = 312
# (313, '2387', '精元')
# 精元
# Not support ID = 313
# (314, '2388', '威盛')
# 威盛
# Not support ID = 314
# (315, '2390', '云辰')
# 云辰
# Not support ID = 315
# (316, '2392', '正崴')
# 正崴
# Not support ID = 316
# (317, '2393', '億光')
# 億光
# Not support ID = 317
# (318, '2395', '研華')
# 研華
# Not support ID = 318
# (319, '2397', '友通')
# 友通
# Not support ID = 319
# (320, '2399', '映泰')
# 映泰
# Not support ID = 320
# (321, '2401', '凌陽')
# 凌陽
# Not support ID = 321
# (322, '2402', '毅嘉')
# 毅嘉
# Not support ID = 322
# (323, '2404', '漢唐')
# 漢唐
# Not support ID = 323
# (324, '2405', '浩鑫')
# 浩鑫
# Not support ID = 324
# (325, '2406', '國碩')
# 國碩
# Not support ID = 325
# (326, '2408', '南亞科')
# 南亞科
# Not support ID = 326
# (327, '2409', '友達')
# 友達
# Not support ID = 327
# (328, '2412', '中華電')
# 中華電
# Not support ID = 328
# (329, '2413', '環科')
# 環科
# Not support ID = 329
# (330, '2414', '精技')
# 精技
# Not support ID = 330
# (331, '2415', '錩新')
# 錩新
# Not support ID = 331
# (332, '2417', '圓剛')
# 圓剛
# Not support ID = 332
# (333, '2419', '仲琦')
# 仲琦
# Not support ID = 333
# (334, '2420', '新巨')
# 新巨
# Not support ID = 334
# (335, '2421', '建準')
# 建準
# Not support ID = 335
# (336, '2423', '固緯')
# 固緯
# Not support ID = 336
# (337, '2424', '隴華')
# 隴華
# Not support ID = 337
# (338, '2425', '承啟')
# 承啟
# Not support ID = 338
# (339, '2426', '鼎元')
# 鼎元
# Not support ID = 339
# (340, '2427', '三商電')
# 三商電
# Not support ID = 340
# (341, '2428', '興勤')
# 興勤
# Not support ID = 341
# (342, '2429', '銘旺科')
# 銘旺科
# Not support ID = 342
# (343, '2430', '燦坤')
# 燦坤
# Not support ID = 343
# (344, '2431', '聯昌')
# 聯昌
# Not support ID = 344
# (345, '2433', '互盛電')
# 互盛電
# Not support ID = 345
# (346, '2434', '統懋')
# 統懋
# Not support ID = 346
# (347, '2436', '偉詮電')
# 偉詮電
# Not support ID = 347
# (348, '2437', '旺詮')
# 旺詮
# Not support ID = 348
# (349, '2438', '翔耀')
# 翔耀
# Not support ID = 349
# (350, '2439', '美律')
# 美律
# Not support ID = 350
# (351, '2440', '太空梭')
# 太空梭
# Not support ID = 351
# (352, '2441', '超豐')
# 超豐
# Not support ID = 352
# (353, '2442', '新美齊')
# 新美齊
# Not support ID = 353
# (354, '2443', '新利虹')
# 新利虹
# Not support ID = 354
# (355, '2444', '友旺')
# 友旺
# Not support ID = 355
# (356, '2448', '晶電')
# 晶電
# Not support ID = 356
# (357, '2449', '京元電子')
# 京元電子
# Not support ID = 357
# (358, '2450', '神腦')
# 神腦
# Not support ID = 358
# (359, '2451', '創見')
# 創見
# Not support ID = 359
# (360, '2453', '凌群')
# 凌群
# Not support ID = 360
# (361, '2454', '聯發科')
# 聯發科
# Not support ID = 361
# (362, '2455', '全新')
# 全新
# Not support ID = 362
# (363, '2456', '奇力新')
# 奇力新
# Not support ID = 363
# (364, '2457', '飛宏')
# 飛宏
# Not support ID = 364
# (365, '2458', '義隆')
# 義隆
# Not support ID = 365
# (366, '2459', '敦吉')
# 敦吉
# Not support ID = 366
# (367, '2460', '建通')
# 建通
# Not support ID = 367
# (368, '2461', '光群雷')
# 光群雷
# Not support ID = 368
# (369, '2462', '良得電')
# 良得電
# Not support ID = 369
# (370, '2464', '盟立')
# 盟立
# Not support ID = 370
# (371, '2465', '麗臺')
# 麗臺
# Not support ID = 371
# (372, '2466', '冠西電')
# 冠西電
# Not support ID = 372
# (373, '2467', '志聖')
# 志聖
# Not support ID = 373
# (374, '2468', '華經')
# 華經
# Not support ID = 374
# (375, '2471', '資通')
# 資通
# Not support ID = 375
# (376, '2472', '立隆電')
# 立隆電
# Not support ID = 376
# (377, '2474', '可成')
# 可成
# Not support ID = 377
# (378, '2475', '華映')
# 華映
# Not support ID = 378
# (379, '2476', '鉅祥')
# 鉅祥
# Not support ID = 379
# (380, '2477', '美隆電')
# 美隆電
# Not support ID = 380
# (381, '2478', '大毅')
# 大毅
# Not support ID = 381
# (382, '2480', '敦陽科')
# 敦陽科
# Not support ID = 382
# (383, '2481', '強茂')
# 強茂
# Not support ID = 383
# (384, '2482', '連宇')
# 連宇
# Not support ID = 384
# (385, '2483', '百容')
# 百容
# Not support ID = 385
# (386, '2484', '希華')
# 希華
# Not support ID = 386
# (387, '2485', '兆赫')
# 兆赫
# Not support ID = 387
# (388, '2486', '一詮')
# 一詮
# Not support ID = 388
# (389, '2488', '漢平')
# 漢平
# Not support ID = 389
# (390, '2489', '瑞軒')
# 瑞軒
# Not support ID = 390
# (391, '2491', '吉祥全')
# 吉祥全
# Not support ID = 391
# (392, '2492', '華新科')
# 華新科
# Not support ID = 392
# (393, '2493', '揚博')
# 揚博
# Not support ID = 393
# (394, '2495', '普安')
# 普安
# Not support ID = 394
# (395, '2496', '卓越')
# 卓越
# Not support ID = 395
# (396, '2497', '怡利電')
# 怡利電
# Not support ID = 396
# (397, '2498', '宏達電')
# 宏達電
# Not support ID = 397
# (398, '2499', '東貝')
# 東貝
# Not support ID = 398
# (399, '2501', '國建')
# 國建
# Not support ID = 399
# (400, '2504', '國產')
# 國產
# Not support ID = 400
# (401, '2505', '國揚')
# 國揚
# Not support ID = 401
# (402, '2506', '太設')
# 太設
# Not support ID = 402
# (403, '2509', '全坤建')
# 全坤建
# Not support ID = 403
# (404, '2511', '太子')
# 太子
# Not support ID = 404
# (405, '2514', '龍邦')
# 龍邦
# Not support ID = 405
# (406, '2515', '中工')
# 中工
# Not support ID = 406
# (407, '2516', '新建')
# 新建
# Not support ID = 407
# (408, '2520', '冠德')
# 冠德
# Not support ID = 408
# (409, '2524', '京城')
# 京城
# Not support ID = 409
# (410, '2527', '宏璟')
# 宏璟
# Not support ID = 410
# (411, '2528', '皇普')
# 皇普
# Not support ID = 411
# (412, '2530', '華建')
# 華建
# Not support ID = 412
# (413, '2534', '宏盛')
# 宏盛
# Not support ID = 413
# (414, '2535', '達欣工')
# 達欣工
# Not support ID = 414
# (415, '2536', '宏普')
# 宏普
# Not support ID = 415
# (416, '2537', '聯上發')
# 聯上發
# Not support ID = 416
# (417, '2538', '基泰')
# 基泰
# Not support ID = 417
# (418, '2539', '櫻花建')
# 櫻花建
# Not support ID = 418
# (419, '2540', '愛山林')
# 愛山林
# Not support ID = 419
# (420, '2542', '興富發')
# 興富發
# Not support ID = 420
# (421, '2543', '皇昌')
# 皇昌
# Not support ID = 421
# (422, '2545', '皇翔')
# 皇翔
# Not support ID = 422
# (423, '2546', '根基')
# 根基
# Not support ID = 423
# (424, '2547', '日勝生')
# 日勝生
# Not support ID = 424
# (425, '2548', '華固')
# 華固
# Not support ID = 425
# (426, '2597', '潤弘')
# 潤弘
# Not support ID = 426
# (427, '2601', '益航')
# 益航
# Not support ID = 427
# (428, '2603', '長榮')
# 長榮
# Not support ID = 428
# (429, '2605', '新興')
# 新興
# Not support ID = 429
# (430, '2606', '裕民')
# 裕民
# Not support ID = 430
# (431, '2607', '榮運')
# 榮運
# Not support ID = 431
# (432, '2608', '大榮')
# 大榮
# Not support ID = 432
# (433, '2609', '陽明')
# 陽明
# Not support ID = 433
# (434, '2610', '華航')
# 華航
# Not support ID = 434
# (435, '2611', '志信')
# 志信
# Not support ID = 435
# (436, '2612', '中航')
# 中航
# Not support ID = 436
# (437, '2613', '中櫃')
# 中櫃
# Not support ID = 437
# (438, '2614', '東森')
# 東森
# Not support ID = 438
# (439, '2615', '萬海')
# 萬海
# Not support ID = 439
# (440, '2616', '山隆')
# 山隆
# Not support ID = 440
# (441, '2617', '台航')
# 台航
# Not support ID = 441
# (442, '2618', '長榮航')
# 長榮航
# Not support ID = 442
# (443, '2633', '台灣高鐵')
# 台灣高鐵
# Not support ID = 443
# (444, '2634', '漢翔')
# 漢翔
# Not support ID = 444
# (445, '2636', '台驊投控')
# 台驊投控
# Not support ID = 445
# (446, '2637', '慧洋-KY')
# 慧洋-KY
# Not support ID = 446
# (447, '2642', '宅配通')
# 宅配通
# Not support ID = 447
# (448, '2701', '萬企')
# 萬企
# Not support ID = 448
# (449, '2702', '華園')
# 華園
# Not support ID = 449
# (450, '2704', '國賓')
# 國賓
# Not support ID = 450
# (451, '2705', '六福')
# 六福
# Not support ID = 451
# (452, '2706', '第一店')
# 第一店
# Not support ID = 452
# (453, '2707', '晶華')
# 晶華
# Not support ID = 453
# (454, '2712', '遠雄來')
# 遠雄來
# Not support ID = 454
# (455, '2722', '夏都')
# 夏都
# Not support ID = 455
# (456, '2723', '美食-KY')
# 美食-KY
# Not support ID = 456
# (457, '2727', '王品')
# 王品
# Not support ID = 457
# (458, '2731', '雄獅')
# 雄獅
# Not support ID = 458
# (459, '2739', '寒舍')
# 寒舍
# Not support ID = 459
# (460, '2748', '雲品')
# 雲品
# Not support ID = 460
# (461, '2801', '彰銀')
# 彰銀
# Not support ID = 461
# (462, '2809', '京城銀')
# 京城銀
# Not support ID = 462
# (463, '2812', '台中銀')
# 台中銀
# Not support ID = 463
# (464, '2816', '旺旺保')
# 旺旺保
# Not support ID = 464
# (465, '2820', '華票')
# 華票
# Not support ID = 465
# (466, '2823', '中壽')
# 中壽
# Not support ID = 466
# (467, '2832', '台產')
# 台產
# Not support ID = 467
# (468, '2834', '臺企銀')
# 臺企銀
# Not support ID = 468
# (469, '2836', '高雄銀')
# 高雄銀
# Not support ID = 469
# (470, '2838', '聯邦銀')
# 聯邦銀
# Not support ID = 470
# (471, '2841', '台開')
# 台開
# Not support ID = 471
# (472, '2845', '遠東銀')
# 遠東銀
# Not support ID = 472
# (473, '2849', '安泰銀')
# 安泰銀
# Not support ID = 473
# (474, '2850', '新產')
# 新產
# Not support ID = 474
# (475, '2851', '中再保')
# 中再保
# Not support ID = 475
# (476, '2852', '第一保')
# 第一保
# Not support ID = 476
# (477, '2855', '統一證')
# 統一證
# Not support ID = 477
# (478, '2856', '元富證')
# 元富證
# Not support ID = 478
# (479, '2867', '三商壽')
# 三商壽
# Not support ID = 479
# (480, '2880', '華南金')
# 華南金
# Not support ID = 480
# (481, '2881', '富邦金')
# 富邦金
# Not support ID = 481
# (482, '2882', '國泰金')
# 國泰金
# Not support ID = 482
# (483, '2883', '開發金')
# 開發金
# Not support ID = 483
# (484, '2884', '玉山金')
# 玉山金
# Not support ID = 484
# (485, '2885', '元大金')
# 元大金
# Not support ID = 485
# (486, '2886', '兆豐金')
# 兆豐金
# Not support ID = 486
# (487, '2887', '台新金')
# 台新金
# Not support ID = 487
# (488, '2888', '新光金')
# 新光金
# Not support ID = 488
# (489, '2889', '國票金')
# 國票金
# Not support ID = 489
# (490, '2890', '永豐金')
# 永豐金
# Not support ID = 490
# (491, '2891', '中信金')
# 中信金
# Not support ID = 491
# (492, '2892', '第一金')
# 第一金
# Not support ID = 492
# (493, '2901', '欣欣')
# 欣欣
# Not support ID = 493
# (494, '2903', '遠百')
# 遠百
# Not support ID = 494
# (495, '2904', '匯僑')
# 匯僑
# Not support ID = 495
# (496, '2905', '三商')
# 三商
# Not support ID = 496
# (497, '2906', '高林')
# 高林
# Not support ID = 497
# (498, '2908', '特力')
# 特力
# Not support ID = 498
# (499, '2910', '統領')
# 統領
# Not support ID = 499
# (500, '2911', '麗嬰房')
# 麗嬰房
# Not support ID = 500
# (501, '2912', '統一超')
# 統一超
# Not support ID = 501
# (502, '2913', '農林')
# 農林
# Not support ID = 502
# (503, '2915', '潤泰全')
# 潤泰全
# Not support ID = 503
# (504, '2923', '鼎固-KY')
# 鼎固-KY
# Not support ID = 504
# (505, '2929', '淘帝-KY')
# 淘帝-KY
# Not support ID = 505
# (506, '2936', '客思達-KY')
# 客思達-KY
# Not support ID = 506
# (507, '3002', '歐格')
# 歐格
# Not support ID = 507
# (508, '3003', '健和興')
# 健和興
# Not support ID = 508
# (509, '3004', '豐達科')
# 豐達科
# Not support ID = 509
# (510, '3005', '神基')
# 神基
# Not support ID = 510
# (511, '3006', '晶豪科')
# 晶豪科
# Not support ID = 511
# (512, '3008', '大立光')
# 大立光
# Not support ID = 512
# (513, '3010', '華立')
# 華立
# Not support ID = 513
# (514, '3011', '今皓')
# 今皓
# Not support ID = 514
# (515, '3013', '晟銘電')
# 晟銘電
# Not support ID = 515
# (516, '3014', '聯陽')
# 聯陽
# Not support ID = 516
# (517, '3015', '全漢')
# 全漢
# Not support ID = 517
# (518, '3016', '嘉晶')
# 嘉晶
# Not support ID = 518
# (519, '3017', '奇鋐')
# 奇鋐
# Not support ID = 519
# (520, '3018', '同開')
# 同開
# Not support ID = 520
# (521, '3019', '亞光')
# 亞光
# Not support ID = 521
# (522, '3021', '鴻名')
# 鴻名
# Not support ID = 522
# (523, '3022', '威強電')
# 威強電
# Not support ID = 523
# (524, '3023', '信邦')
# 信邦
# Not support ID = 524
# (525, '3024', '憶聲')
# 憶聲
# Not support ID = 525
# (526, '3025', '星通')
# 星通
# Not support ID = 526
# (527, '3026', '禾伸堂')
# 禾伸堂
# Not support ID = 527
# (528, '3027', '盛達')
# 盛達
# Not support ID = 528
# (529, '3028', '增你強')
# 增你強
# Not support ID = 529
# (530, '3029', '零壹')
# 零壹
# Not support ID = 530
# (531, '3030', '德律')
# 德律
# Not support ID = 531
# (532, '3031', '佰鴻')
# 佰鴻
# Not support ID = 532
# (533, '3032', '偉訓')
# 偉訓
# Not support ID = 533
# (534, '3033', '威健')
# 威健
# Not support ID = 534
# (535, '3034', '聯詠')
# 聯詠
# Not support ID = 535
# (536, '3035', '智原')
# 智原
# Not support ID = 536
# (537, '3036', '文曄')
# 文曄
# Not support ID = 537
# (538, '3037', '欣興')
# 欣興
# Not support ID = 538
# (539, '3038', '全台')
# 全台
# Not support ID = 539
# (540, '3040', '遠見')
# 遠見
# Not support ID = 540
# (541, '3041', '揚智')
# 揚智
# Not support ID = 541
# (542, '3042', '晶技')
# 晶技
# Not support ID = 542
# (543, '3043', '科風')
# 科風
# Not support ID = 543
# (544, '3044', '健鼎')
# 健鼎
# Not support ID = 544
# (545, '3045', '台灣大')
# 台灣大
# Not support ID = 545
# (546, '3046', '建??')
# 建??
# Not support ID = 546
# (547, '3047', '訊舟')
# 訊舟
# Not support ID = 547
# (548, '3048', '益登')
# 益登
# Not support ID = 548
# (549, '3049', '和鑫')
# 和鑫
# Not support ID = 549
# (550, '3050', '鈺德')
# 鈺德
# Not support ID = 550
# (551, '3051', '力特')
# 力特
# Not support ID = 551
# (552, '3052', '夆典')
# 夆典
# Not support ID = 552
# (553, '3054', '立萬利')
# 立萬利
# Not support ID = 553
# (554, '3055', '蔚華科')
# 蔚華科
# Not support ID = 554
# (555, '3056', '總太')
# 總太
# Not support ID = 555
# (556, '3057', '喬鼎')
# 喬鼎
# Not support ID = 556
# (557, '3058', '立德')
# 立德
# Not support ID = 557
# (558, '3059', '華晶科')
# 華晶科
# Not support ID = 558
# (559, '3060', '銘異')
# 銘異
# Not support ID = 559
# (560, '3062', '建漢')
# 建漢
# Not support ID = 560
# (561, '3090', '日電貿')
# 日電貿
# Not support ID = 561
# (562, '3094', '聯傑')
# 聯傑
# Not support ID = 562
# (563, '3130', '一零四')
# 一零四
# Not support ID = 563
# (564, '3149', '正達')
# 正達
# Not support ID = 564
# (565, '3164', '景岳')
# 景岳
# Not support ID = 565
# (566, '3167', '大量')
# 大量
# Not support ID = 566
# (567, '3189', '景碩')
# 景碩
# Not support ID = 567
# (568, '3209', '全科')
# 全科
# Not support ID = 568
# (569, '3229', '晟鈦')
# 晟鈦
# Not support ID = 569
# (570, '3231', '緯創')
# 緯創
# Not support ID = 570
# (571, '3257', '虹冠電')
# 虹冠電
# Not support ID = 571
# (572, '3266', '昇陽')
# 昇陽
# Not support ID = 572
# (573, '3296', '勝德')
# 勝德
# Not support ID = 573
# (574, '3305', '昇貿')
# 昇貿
# Not support ID = 574
# (575, '3308', '聯德')
# 聯德
# Not support ID = 575
# (576, '3311', '閎暉')
# 閎暉
# Not support ID = 576
# (577, '3312', '弘憶股')
# 弘憶股
# Not support ID = 577
# (578, '3315', '宣昶')
# 宣昶
# Not support ID = 578
# (579, '3321', '同泰')
# 同泰
# Not support ID = 579
# (580, '3338', '泰碩')
# 泰碩
# Not support ID = 580
# (581, '3346', '麗清')
# 麗清
# Not support ID = 581
# (582, '3356', '奇偶')
# 奇偶
# Not support ID = 582
# (583, '3376', '新日興')
# 新日興
# Not support ID = 583
# (584, '3380', '明泰')
# 明泰
# Not support ID = 584
# (585, '3383', '新世紀')
# 新世紀
# Not support ID = 585
# (586, '3406', '玉晶光')
# 玉晶光
# Not support ID = 586
# (587, '3413', '京鼎')
# 京鼎
# Not support ID = 587
# (588, '3416', '融程電')
# 融程電
# Not support ID = 588
# (589, '3419', '譁裕')
# 譁裕
# Not support ID = 589
# (590, '3432', '台端')
# 台端
# Not support ID = 590
# (591, '3437', '榮創')
# 榮創
# Not support ID = 591
# (592, '3443', '創意')
# 創意
# Not support ID = 592
# (593, '3450', '聯鈞')
# 聯鈞
# Not support ID = 593
# (594, '3454', '晶睿')
# 晶睿
# Not support ID = 594
# (595, '3481', '群創')
# 群創
# Not support ID = 595
# (596, '3494', '誠研')
# 誠研
# Not support ID = 596
# (597, '3501', '維熹')
# 維熹
# Not support ID = 597
# (598, '3504', '揚明光')
# 揚明光
# Not support ID = 598
# (599, '3514', '昱晶')
# 昱晶
# Not support ID = 599
# (600, '3515', '華擎')
# 華擎
# Not support ID = 600
# (601, '3518', '柏騰')
# 柏騰
# Not support ID = 601
# (602, '3519', '綠能')
# 綠能
# Not support ID = 602
# (603, '3528', '安馳')
# 安馳
# Not support ID = 603
# (604, '3532', '台勝科')
# 台勝科
# Not support ID = 604
# (605, '3533', '嘉澤')
# 嘉澤
# Not support ID = 605
# (606, '3535', '晶彩科')
# 晶彩科
# Not support ID = 606
# (607, '3536', '誠創')
# 誠創
# Not support ID = 607
# (608, '3545', '敦泰')
# 敦泰
# Not support ID = 608
# (609, '3550', '聯穎')
# 聯穎
# Not support ID = 609
# (610, '3557', '嘉威')
# 嘉威
# Not support ID = 610
# (611, '3559', '全智科')
# 全智科
# Not support ID = 611
# (612, '3561', '昇陽光電')
# 昇陽光電
# Not support ID = 612
# (613, '3576', '新日光')
# 新日光
# Not support ID = 613
# (614, '3579', '尚志')
# 尚志
# Not support ID = 614
# (615, '3583', '辛耘')
# 辛耘
# Not support ID = 615
# (616, '3588', '通嘉')
# 通嘉
# Not support ID = 616
# (617, '3591', '艾笛森')
# 艾笛森
# Not support ID = 617
# (618, '3593', '力銘')
# 力銘
# Not support ID = 618
# (619, '3596', '智易')
# 智易
# Not support ID = 619
# (620, '3605', '宏致')
# 宏致
# Not support ID = 620
# (621, '3607', '谷崧')
# 谷崧
# Not support ID = 621
# (622, '3617', '碩天')
# 碩天
# Not support ID = 622
# (623, '3622', '洋華')
# 洋華
# Not support ID = 623
# (624, '3645', '達邁')
# 達邁
# Not support ID = 624
# (625, '3653', '健策')
# 健策
# Not support ID = 625
# (626, '3661', '世芯-KY')
# 世芯-KY
# Not support ID = 626
# (627, '3665', '貿聯-KY')
# 貿聯-KY
# Not support ID = 627
# (628, '3669', '圓展')
# 圓展
# Not support ID = 628
# (629, '3673', 'TPK-KY')
# TPK-KY
# Not support ID = 629
# (630, '3679', '新至陞')
# 新至陞
# Not support ID = 630
# (631, '3682', '亞太電')
# 亞太電
# Not support ID = 631
# (632, '3686', '達能')
# 達能
# Not support ID = 632
# (633, '3694', '海華')
# 海華
# Not support ID = 633
# (634, '3698', '隆達')
# 隆達
# Not support ID = 634
# (635, '3701', '大眾控')
# 大眾控
# Not support ID = 635
# (636, '3702', '大聯大')
# 大聯大
# Not support ID = 636
# (637, '3703', '欣陸')
# 欣陸
# Not support ID = 637
# (638, '3704', '合勤控')
# 合勤控
# Not support ID = 638
# (639, '3705', '永信')
# 永信
# Not support ID = 639
# (640, '3706', '神達')
# 神達
# Not support ID = 640
# (641, '3708', '上緯投控')
# 上緯投控
# Not support ID = 641
# (642, '4104', '佳醫')
# 佳醫
# Not support ID = 642
# (643, '4106', '雃博')
# 雃博
# Not support ID = 643
# (644, '4108', '懷特')
# 懷特
# Not support ID = 644
# (645, '4119', '旭富')
# 旭富
# Not support ID = 645
# (646, '4133', '亞諾法')
# 亞諾法
# Not support ID = 646
# (647, '4137', '麗豐-KY')
# 麗豐-KY
# Not support ID = 647
# (648, '4141', '龍燈-KY')
# 龍燈-KY
# Not support ID = 648
# (649, '4142', '國光生')
# 國光生
# Not support ID = 649
# (650, '4144', '康聯-KY')
# 康聯-KY
# Not support ID = 650
# (651, '4164', '承業醫')
# 承業醫
# Not support ID = 651
# (652, '4190', '佐登-KY')
# 佐登-KY
# Not support ID = 652
# (653, '4306', '炎洲')
# 炎洲
# Not support ID = 653
# (654, '4414', '如興')
# 如興
# Not support ID = 654
# (655, '4426', '利勤')
# 利勤
# Not support ID = 655
# (656, '4438', '廣越')
# 廣越
# Not support ID = 656
# (657, '4526', '東台')
# 東台
# Not support ID = 657
# (658, '4532', '瑞智')
# 瑞智
# Not support ID = 658
# (659, '4536', '拓凱')
# 拓凱
# Not support ID = 659
# (660, '4545', '銘鈺')
# 銘鈺
# Not support ID = 660
# (661, '4551', '智伸科')
# 智伸科
# Not support ID = 661
# (662, '4552', '力達-KY')
# 力達-KY
# Not support ID = 662
# (663, '4555', '氣立')
# 氣立
# Not support ID = 663
# (664, '4557', '永新-KY')
# 永新-KY
# Not support ID = 664
# (665, '4720', '德淵')
# 德淵
# Not support ID = 665
# (666, '4722', '國精化')
# 國精化
# Not support ID = 666
# (667, '4725', '信昌化')
# 信昌化
# Not support ID = 667
# (668, '4737', '華廣')
# 華廣
# Not support ID = 668
# (669, '4746', '台耀')
# 台耀
# Not support ID = 669
# (670, '4755', '三福化')
# 三福化
# Not support ID = 670
# (671, '4763', '材料-KY')
# 材料-KY
# Not support ID = 671
# (672, '4904', '遠傳')
# 遠傳
# Not support ID = 672
# (673, '4906', '正文')
# 正文
# Not support ID = 673
# (674, '4912', '聯德控股-KY')
# 聯德控股-KY
# Not support ID = 674
# (675, '4915', '致伸')
# 致伸
# Not support ID = 675
# (676, '4916', '事欣科')
# 事欣科
# Not support ID = 676
# (677, '4919', '新唐')
# 新唐
# Not support ID = 677
# (678, '4927', '泰鼎-KY')
# 泰鼎-KY
# Not support ID = 678
# (679, '4930', '燦星網')
# 燦星網
# Not support ID = 679
# (680, '4934', '太極')
# 太極
# Not support ID = 680
# (681, '4935', '茂林-KY')
# 茂林-KY
# Not support ID = 681
# (682, '4938', '和碩')
# 和碩
# Not support ID = 682
# (683, '4942', '嘉彰')
# 嘉彰
# Not support ID = 683
# (684, '4943', '康控-KY')
# 康控-KY
# Not support ID = 684
# (685, '4952', '凌通')
# 凌通
# Not support ID = 685
# (686, '4956', '光鋐')
# 光鋐
# Not support ID = 686
# (687, '4958', '臻鼎-KY')
# 臻鼎-KY
# Not support ID = 687
# (688, '4960', '奇美材')
# 奇美材
# Not support ID = 688
# (689, '4968', '立積')
# 立積
# Not support ID = 689
# (690, '4976', '佳凌')
# 佳凌
# Not support ID = 690
# (691, '4977', '眾達-KY')
# 眾達-KY
# Not support ID = 691
# (692, '4984', '科納-KY')
# 科納-KY
# Not support ID = 692
# (693, '4994', '傳奇')
# 傳奇
# Not support ID = 693
# (694, '4999', '鑫禾')
# 鑫禾
# Not support ID = 694
# (695, '5007', '三星')
# 三星
# Not support ID = 695
# (696, '5203', '訊連')
# 訊連
# Not support ID = 696
# (697, '5215', '科嘉-KY')
# 科嘉-KY
# Not support ID = 697
# (698, '5225', '東科-KY')
# 東科-KY
# Not support ID = 698
# (699, '5234', '達興材料')
# 達興材料
# Not support ID = 699
# (700, '5243', '乙盛-KY')
# 乙盛-KY
# Not support ID = 700
# (701, '5258', '虹堡')
# 虹堡
# Not support ID = 701
# (702, '5259', '清惠')
# 清惠
# Not support ID = 702
# (703, '5264', '鎧勝-KY')
# 鎧勝-KY
# Not support ID = 703
# (704, '5269', '祥碩')
# 祥碩
# Not support ID = 704
# (705, '5284', 'jpp-KY')
# jpp-KY
# Not support ID = 705
# (706, '5285', '界霖')
# 界霖
# Not support ID = 706
# (707, '5288', '豐祥-KY')
# 豐祥-KY
# Not support ID = 707
# (708, '5305', '敦南')
# 敦南
# Not support ID = 708
# (709, '5388', '中磊')
# 中磊
# Not support ID = 709
# (710, '5434', '崇越')
# 崇越
# Not support ID = 710
# (711, '5469', '瀚宇博')
# 瀚宇博
# Not support ID = 711
# (712, '5471', '松翰')
# 松翰
# Not support ID = 712
# (713, '5484', '慧友')
# 慧友
# Not support ID = 713
# (714, '5515', '建國')
# 建國
# Not support ID = 714
# (715, '5519', '隆大')
# 隆大
# Not support ID = 715
# (716, '5521', '工信')
# 工信
# Not support ID = 716
# (717, '5522', '遠雄')
# 遠雄
# Not support ID = 717
# (718, '5525', '順天')
# 順天
# Not support ID = 718
# (719, '5531', '鄉林')
# 鄉林
# Not support ID = 719
# (720, '5533', '皇鼎')
# 皇鼎
# Not support ID = 720
# (721, '5534', '長虹')
# 長虹
# Not support ID = 721
# (722, '5538', '東明-KY')
# 東明-KY
# Not support ID = 722
# (723, '5607', '遠雄港')
# 遠雄港
# Not support ID = 723
# (724, '5608', '四維航')
# 四維航
# Not support ID = 724
# (725, '5706', '鳳凰')
# 鳳凰
# Not support ID = 725
# (726, '5871', '中租-KY')
# 中租-KY
# Not support ID = 726
# (727, '5880', '合庫金')
# 合庫金
# Not support ID = 727
# (728, '5906', '台南-KY')
# 台南-KY
# Not support ID = 728
# (729, '5907', '大洋-KY')
# 大洋-KY
# Not support ID = 729
# (730, '6005', '群益證')
# 群益證
# Not support ID = 730
# (731, '6108', '競國')
# 競國
# Not support ID = 731
# (732, '6112', '聚碩')
# 聚碩
# Not support ID = 732
# (733, '6115', '鎰勝')
# 鎰勝
# Not support ID = 733
# (734, '6116', '彩晶')
# 彩晶
# Not support ID = 734
# (735, '6117', '迎廣')
# 迎廣
# Not support ID = 735
# (736, '6120', '達運')
# 達運
# Not support ID = 736
# (737, '6128', '上福')
# 上福
# Not support ID = 737
# (738, '6131', '悠克')
# 悠克
# Not support ID = 738
# (739, '6133', '金橋')
# 金橋
# Not support ID = 739
# (740, '6136', '富爾特')
# 富爾特
# Not support ID = 740
# (741, '6139', '亞翔')
# 亞翔
# Not support ID = 741
# (742, '6141', '柏承')
# 柏承
# Not support ID = 742
# (743, '6142', '友勁')
# 友勁
# Not support ID = 743
# (744, '6145', '勁永')
# 勁永
# Not support ID = 744
# (745, '6152', '百一')
# 百一
# Not support ID = 745
# (746, '6153', '嘉聯益')
# 嘉聯益
# Not support ID = 746
# (747, '6155', '鈞寶')
# 鈞寶
# Not support ID = 747
# (748, '6164', '華興')
# 華興
# Not support ID = 748
# (749, '6165', '捷泰')
# 捷泰
# Not support ID = 749
# (750, '6166', '凌華')
# 凌華
# Not support ID = 750
# (751, '6168', '宏齊')
# 宏齊
# Not support ID = 751
# (752, '6172', '互億')
# 互億
# Not support ID = 752
# (753, '6176', '瑞儀')
# 瑞儀
# Not support ID = 753
# (754, '6177', '達麗')
# 達麗
# Not support ID = 754
# (755, '6183', '關貿')
# 關貿
# Not support ID = 755
# (756, '6184', '大豐電')
# 大豐電
# Not support ID = 756
# (757, '6189', '豐藝')
# 豐藝
# Not support ID = 757
# (758, '6191', '精成科')
# 精成科
# Not support ID = 758
# (759, '6192', '巨路')
# 巨路
# Not support ID = 759
# (760, '6196', '帆宣')
# 帆宣
# Not support ID = 760
# (761, '6197', '佳必琪')
# 佳必琪
# Not support ID = 761
# (762, '6201', '亞弘電')
# 亞弘電
# Not support ID = 762
# (763, '6202', '盛群')
# 盛群
# Not support ID = 763
# (764, '6205', '詮欣')
# 詮欣
# Not support ID = 764
# (765, '6206', '飛捷')
# 飛捷
# Not support ID = 765
# (766, '6209', '今國光')
# 今國光
# Not support ID = 766
# (767, '6213', '聯茂')
# 聯茂
# Not support ID = 767
# (768, '6214', '精誠')
# 精誠
# Not support ID = 768
# (769, '6215', '和椿')
# 和椿
# Not support ID = 769
# (770, '6216', '居易')
# 居易
# Not support ID = 770
# (771, '6224', '聚鼎')
# 聚鼎
# Not support ID = 771
# (772, '6225', '天瀚')
# 天瀚
# Not support ID = 772
# (773, '6226', '光鼎')
# 光鼎
# Not support ID = 773
# (774, '6230', '超眾')
# 超眾
# Not support ID = 774
# (775, '6235', '華孚')
# 華孚
# Not support ID = 775
# (776, '6239', '力成')
# 力成
# Not support ID = 776
# (777, '6243', '迅杰')
# 迅杰
# Not support ID = 777
# (778, '6251', '定穎')
# 定穎
# Not support ID = 778
# (779, '6257', '矽格')
# 矽格
# Not support ID = 779
# (780, '6269', '台郡')
# 台郡
# Not support ID = 780
# (781, '6271', '同欣電')
# 同欣電
# Not support ID = 781
# (782, '6277', '宏正')
# 宏正
# Not support ID = 782
# (783, '6278', '台表科')
# 台表科
# Not support ID = 783
# (784, '6281', '全國電')
# 全國電
# Not support ID = 784
# (785, '6282', '康舒')
# 康舒
# Not support ID = 785
# (786, '6283', '淳安')
# 淳安
# Not support ID = 786
# (787, '6285', '啟??')
# 啟??
# Not support ID = 787
# (788, '6289', '華上')
# 華上
# Not support ID = 788
# (789, '6405', '悅城')
# 悅城
# Not support ID = 789
# (790, '6409', '旭隼')
# 旭隼
# Not support ID = 790
# (791, '6412', '群電')
# 群電
# Not support ID = 791
# (792, '6414', '樺漢')
# 樺漢
# Not support ID = 792
# (793, '6415', '矽力-KY')
# 矽力-KY
# Not support ID = 793
# (794, '6422', '君耀-KY')
# 君耀-KY
# Not support ID = 794
# (795, '6431', '光麗-KY')
# 光麗-KY
# Not support ID = 795
# (796, '6442', '光聖')
# 光聖
# Not support ID = 796
# (797, '6443', '元晶')
# 元晶
# Not support ID = 797
# (798, '6449', '鈺邦')
# 鈺邦
# Not support ID = 798
# (799, '6451', '訊芯-KY')
# 訊芯-KY
# Not support ID = 799
# (800, '6452', '康友-KY')
# 康友-KY
# Not support ID = 800
# (801, '6456', 'GIS-KY')
# GIS-KY
# Not support ID = 801
# (802, '6464', '台數科')
# 台數科
# Not support ID = 802
# (803, '6477', '安集')
# 安集
# Not support ID = 803
# (804, '6504', '南六')
# 南六
# Not support ID = 804
# (805, '6505', '台塑化')
# 台塑化
# Not support ID = 805
# (806, '6525', '捷敏-KY')
# 捷敏-KY
# Not support ID = 806
# (807, '6531', '愛普')
# 愛普
# Not support ID = 807
# (808, '6533', '晶心科')
# 晶心科
# Not support ID = 808
# (809, '6552', '易華電')
# 易華電
# Not support ID = 809
# (810, '6605', '帝寶')
# 帝寶
# Not support ID = 810
# (811, '8011', '台通')
# 台通
# Not support ID = 811
# (812, '8016', '矽創')
# 矽創
# Not support ID = 812
# (813, '8021', '尖點')
# 尖點
# Not support ID = 813
# (814, '8033', '雷虎')
# 雷虎
# Not support ID = 814
# (815, '8039', '台虹')
# 台虹
# Not support ID = 815
# (816, '8046', '南電')
# 南電
# Not support ID = 816
# (817, '8070', '長華')
# 長華
# Not support ID = 817
# (818, '8072', '陞泰')
# 陞泰
# Not support ID = 818
# (819, '8081', '致新')
# 致新
# Not support ID = 819
# (820, '8101', '華冠')
# 華冠
# Not support ID = 820
# (821, '8103', '瀚荃')
# 瀚荃
# Not support ID = 821
# (822, '8105', '凌巨')
# 凌巨
# Not support ID = 822
# (823, '8110', '華東')
# 華東
# Not support ID = 823
# (824, '8112', '至上')
# 至上
# Not support ID = 824
# (825, '8114', '振樺電')
# 振樺電
# Not support ID = 825
# (826, '8131', '福懋科')
# 福懋科
# Not support ID = 826
# (827, '8150', '南茂')
# 南茂
# Not support ID = 827
# (828, '8163', '達方')
# 達方
# Not support ID = 828
# (829, '8201', '無敵')
# 無敵
# Not support ID = 829
# (830, '8210', '勤誠')
# 勤誠
# Not support ID = 830
# (831, '8213', '志超')
# 志超
# Not support ID = 831
# (832, '8215', '明基材')
# 明基材
# Not support ID = 832
# (833, '8222', '寶一')
# 寶一
# Not support ID = 833
# (834, '8249', '菱光')
# 菱光
# Not support ID = 834
# (835, '8261', '富鼎')
# 富鼎
# Not support ID = 835
# (836, '8271', '宇瞻')
# 宇瞻
# Not support ID = 836
# (837, '8341', '日友')
# 日友
# Not support ID = 837
# (838, '8374', '羅昇')
# 羅昇
# Not support ID = 838
# (839, '8404', '百和興業-KY')
# 百和興業-KY
# Not support ID = 839
# (840, '8411', '福貞-KY')
# 福貞-KY
# Not support ID = 840
# (841, '8422', '可寧衛')
# 可寧衛
# Not support ID = 841
# (842, '8427', '基勝-KY')
# 基勝-KY
# Not support ID = 842
# (843, '8429', '金麗-KY')
# 金麗-KY
# Not support ID = 843
# (844, '8442', '威宏-KY')
# 威宏-KY
# Not support ID = 844
# (845, '8443', '阿瘦')
# 阿瘦
# Not support ID = 845
# (846, '8454', '富邦媒')
# 富邦媒
# Not support ID = 846
# (847, '8463', '潤泰材')
# 潤泰材
# Not support ID = 847
# (848, '8464', '億豐')
# 億豐
# Not support ID = 848
# (849, '8466', '美吉吉-KY')
# 美吉吉-KY
# Not support ID = 849
# (850, '8467', '波力-KY')
# 波力-KY
# Not support ID = 850
# (851, '8473', '山林水')
# 山林水
# Not support ID = 851
# (852, '8480', '泰昇-KY')
# 泰昇-KY
# Not support ID = 852
# (853, '8481', '政伸')
# 政伸
# Not support ID = 853
# (854, '8488', '吉源-KY')
# 吉源-KY
# Not support ID = 854
# (855, '8926', '台汽電')
# 台汽電
# Not support ID = 855
# (856, '8940', '新天地')
# 新天地
# Not support ID = 856
# (857, '8996', '高力')
# 高力
# Not support ID = 857
# (858, '9802', '鈺齊-KY')
# 鈺齊-KY
# Not support ID = 858
# (859, '9902', '台火')
# 台火
# Not support ID = 859
# (860, '9904', '寶成')
# 寶成
# Not support ID = 860
# (861, '9905', '大華')
# 大華
# Not support ID = 861
# (862, '9906', '欣巴巴')
# 欣巴巴
# Not support ID = 862
# (863, '9907', '統一實')
# 統一實
# Not support ID = 863
# (864, '9908', '大台北')
# 大台北
# Not support ID = 864
# (865, '9910', '豐泰')
# 豐泰
# Not support ID = 865
# (866, '9911', '櫻花')
# 櫻花
# Not support ID = 866
# (867, '9912', '偉聯')
# 偉聯
# Not support ID = 867
# (868, '9914', '美利達')
# 美利達
# Not support ID = 868
# (869, '9917', '中保')
# 中保
# Not support ID = 869
# (870, '9918', '欣天然')
# 欣天然
# Not support ID = 870
# (871, '9919', '康那香')
# 康那香
# Not support ID = 871
# (872, '9921', '巨大')
# 巨大
# Not support ID = 872
# (873, '9924', '福興')
# 福興
# Not support ID = 873
# (874, '9925', '新保')
# 新保
# Not support ID = 874
# (875, '9926', '新海')
# 新海
# Not support ID = 875
# (876, '9927', '泰銘')
# 泰銘
# Not support ID = 876
# (877, '9928', '中視')
# 中視
# Not support ID = 877
# (878, '9929', '秋雨')
# 秋雨
# Not support ID = 878
# (879, '9930', '中聯資源')
# 中聯資源
# Not support ID = 879
# (880, '9931', '欣高')
# 欣高
# Not support ID = 880
# (881, '9933', '中鼎')
# 中鼎
# Not support ID = 881
# (882, '9934', '成霖')
# 成霖
# Not support ID = 882
# (883, '9935', '慶豐富')
# 慶豐富
# Not support ID = 883
# (884, '9937', '全國')
# 全國
# Not support ID = 884
# (885, '9938', '百和')
# 百和
# Not support ID = 885
# (886, '9939', '宏全')
# 宏全
# Not support ID = 886
# (887, '9940', '信義')
# 信義
# Not support ID = 887
# (888, '9941', '裕融')
# 裕融
# Not support ID = 888
# (889, '9942', '茂順')
# 茂順
# Not support ID = 889
# (890, '9943', '好樂迪')
# 好樂迪
# Not support ID = 890
# (891, '9944', '新麗')
# 新麗
# Not support ID = 891
# (892, '9945', '潤泰新')
# 潤泰新
# Not support ID = 892
# (893, '9946', '三發地產')
# 三發地產
# Not support ID = 893
# (894, '9955', '佳龍')
# 佳龍
# Not support ID = 894
# (895, '9958', '世紀鋼')
# 世紀鋼
# Not support ID = 895
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# Crawl history is done
